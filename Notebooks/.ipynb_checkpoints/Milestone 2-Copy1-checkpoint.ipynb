# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle, os, glob

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture as GMM
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import pairwise_distances
from scipy.spatial import distance_matrix
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from mpl_toolkits.mplot3d import Axes3D
import time


from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
df_stratified = pickle.load(open("../Data/stratified_data.p", 'rb'))

# %%
df_stratified['articleType'] = df_stratified['articleType'].astype('category')
df_stratified['label'] = df_stratified['articleType'].cat.codes
df_stratified.head()
df_stratified = df_stratified.loc[:, ['id', 'label']]

# %%
df_stratified.head()
# Out:
#       id  label
# 0  55627      0
# 1  23930      0
# 2  22114      0
# 3   8996      0
# 4  24666      0

# %%
img_data = []
for i in df_stratified['id']:
    filepath = 'C:/fashion-dataset/fashion-dataset/images/'+str(i)+'.jpg'  
    temp = load_img(filepath, target_size = (120, 120, 3))
    temp = img_to_array(temp).flatten()
    temp /= 255
    img_data.append(temp)

# %%
img_data
# Out:
# [array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#         0.99215686], dtype=float32),
#  array([0.8392157 , 0.827451  , 0.8       , ..., 0.78039217, 0.76862746,
#         0.7411765 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99215686, 0.99215686, 0.99215686, ..., 0.99215686, 0.99215686,
#         0.99215686], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#         1.        ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.9882353, 0.9882353, 0.9882353, ..., 0.9882353, 0.9882353,
#         0.9882353], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#         1.        ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.93333334, 0.93333334, 0.93333334, ..., 0.93333334, 0.93333334,
#         0.93333334], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7607843 , 0.7490196 , 0.7294118 , ..., 0.7529412 , 0.7411765 ,
#         0.72156864], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#         1.        ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.8745098 , 0.8784314 , 0.8862745 , ..., 0.8784314 , 0.8862745 ,
#         0.88235295], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99215686, 1.        , 0.99607843, ..., 0.99215686, 1.        ,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7529412 , 0.7411765 ,
#         0.72156864], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#         0.99215686], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7607843 , 0.7490196 , 0.7294118 , ..., 0.7529412 , 0.7411765 ,
#         0.72156864], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.75686276, 0.74509805,
#         0.7254902 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#         0.99215686], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.6392157 , 0.63529414, 0.61960787, ..., 0.8784314 , 0.8745098 ,
#         0.89411765], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.75686276, 0.74509805,
#         0.7254902 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#         0.99215686], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.76862746, 0.75686276,
#         0.7294118 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7607843, 0.7490196, 0.7294118, ..., 0.7490196, 0.7372549,
#         0.7176471], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99215686, 0.99215686, 0.99215686, ..., 0.99215686, 0.99215686,
#         0.99215686], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#         1.        ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1.        , 1.        , 1.        , ..., 0.9372549 , 0.9372549 ,
#         0.92941177], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.3137255 , 0.30588236, 0.30980393, ..., 0.8862745 , 0.8862745 ,
#         0.8862745 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.75686276, 0.74509805,
#         0.7254902 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([0.99215686, 0.99215686, 0.99215686, ..., 0.96862745, 0.972549  ,
#         0.9882353 ], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.9882353, 0.9882353, 0.9882353, ..., 0.9882353, 0.9882353,
#         0.9882353], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7529412 , 0.7411765 ,
#         0.72156864], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#         0.99607843], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  array([1., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  ...]

# %%
img_data = np.array(img_data, dtype = float)

# %%
# 88 images with dimension (n_images * (240*180*3)) 
img_data.shape
# Out:
# (5000, 43200)

# %% [markdown]
# ### Employing PCA for ~ 150 Components

# %%
pca = PCA( 
        n_components = 150,
        svd_solver = 'auto')
pca.fit(img_data)
pca_results = pca.transform(img_data)

# %% [markdown]
# ### KMeans After PCA [ Only 150 Components]

# %%
cluster = []
# for i in range(1,6):
kmeans = KMeans(n_clusters = 5)
kmeans.fit(pca_results)
cluster.append(kmeans.predict(pca_results))

# %%
kmeans.cluster_centers_
# Out:
# array([[ 3.42849465e+01,  6.41443281e+00, -1.13100642e+01,
#         -4.12685280e+00, -5.10689347e+00,  1.82281840e+00,
#          5.34045088e-01,  1.01364378e+00,  5.62730143e-01,
#         -9.88910177e-01, -4.30562163e-01, -8.96377177e-01,
#          6.24514334e-01, -8.62180389e-01, -4.09632212e-01,
#          8.43383263e-01,  2.51429781e-01,  3.84166423e-01,
#         -4.04883634e-01,  3.16403639e-02, -1.27214014e-01,
#          4.48740150e-01, -4.97948407e-01,  3.11147959e-01,
#          2.75682119e-01, -1.40444555e-01,  3.93800777e-01,
#         -5.03940848e-01, -1.81617816e-02, -8.86697839e-02,
#         -3.67710892e-01, -5.18252082e-01, -2.96750360e-02,
#          3.04434563e-01,  6.07187495e-01,  8.73445558e-02,
#         -3.93716532e-02,  5.70104360e-02,  1.56899499e-01,
#          1.92389113e-01, -8.62505096e-02, -1.61276340e-01,
#         -1.90736189e-01,  1.19923130e-01,  1.03331283e-01,
#         -1.38075056e-01,  3.45382187e-01, -4.58670986e-02,
#         -8.49929011e-02,  1.35715098e-01,  1.22880455e-01,
#          8.13976959e-02, -6.31589567e-02,  1.59883951e-01,
#         -3.66666411e-02, -1.96760872e-02, -4.68987174e-02,
#          8.48655912e-02, -1.29616675e-01, -1.67560597e-01,
#          1.10652338e-01,  4.44436175e-02, -6.52556858e-02,
#         -9.93819604e-02,  8.76018608e-02, -1.03854798e-01,
#          1.33496897e-01, -2.47887800e-01,  6.67693293e-02,
#         -2.20941752e-01,  1.17917105e-01, -1.31216025e-01,
#          9.89619889e-02, -1.88125805e-02, -5.11508302e-02,
#         -6.39365090e-02, -3.43682987e-02, -2.18200607e-02,
#         -2.40049315e-02, -2.72009413e-02, -6.89639867e-02,
#         -2.83235321e-02, -8.42223914e-02, -1.24412653e-01,
#         -2.89600053e-02, -3.23708326e-02, -5.11263857e-02,
#         -6.28381265e-03,  1.10232309e-02, -3.34339660e-02,
#         -4.40934431e-02,  3.17539894e-02,  9.37824766e-02,
#         -2.06849402e-02, -3.41931468e-03, -3.88920153e-02,
#          1.04986369e-01, -2.64179761e-03, -9.36097175e-04,
#          5.69194281e-02,  6.17036132e-02,  1.71982616e-02,
#          1.33663548e-02,  5.59822642e-02, -2.37854811e-03,
#         -1.87715956e-02,  1.78081674e-02, -2.88758008e-02,
#         -5.59521716e-02,  4.63906905e-02,  5.37043891e-03,
#         -1.67730820e-02, -2.57401438e-02,  1.77890028e-01,
#         -3.31156367e-02,  2.03464941e-02, -2.84056135e-02,
#         -7.49482650e-02,  8.69049966e-03, -5.83140408e-02,
#          1.38831827e-02, -2.60257973e-02,  5.80777868e-04,
#         -3.97988556e-03,  2.20567248e-02, -3.64053041e-02,
#          6.51661878e-02,  3.82055202e-02,  1.85719642e-02,
#         -2.55370539e-02, -5.67623695e-02,  4.34336741e-02,
#         -3.13603506e-02, -6.63285377e-02, -8.27866429e-04,
#          4.10815293e-02,  7.38470766e-02, -5.76803038e-02,
#          4.04985039e-02, -3.54285173e-02, -5.84058027e-02,
#          1.24193761e-01,  8.08989506e-03,  4.05327336e-02,
#          4.48334938e-03,  6.05040639e-02,  2.94026355e-02,
#          6.69279345e-03, -3.20958897e-02,  6.33291225e-02,
#         -3.83130345e-03,  3.14119321e-02,  6.50861378e-02,
#          1.23778656e-02, -1.30156083e-02, -3.09705676e-02,
#         -4.19099463e-02,  2.25724662e-03,  4.61066731e-02,
#         -1.39762589e-02,  5.93771649e-03, -4.75315526e-02,
#          7.25242283e-02,  3.48155456e-02,  1.25939862e-02,
#         -2.62546169e-03, -2.05560978e-02, -1.48521016e-02,
#          4.11488132e-02,  4.43018785e-02,  3.56809901e-02,
#          7.98816587e-04, -2.57625281e-02, -3.40684788e-02]])

# %%
tsne = TSNE(n_components=2, verbose=0, perplexity=30, n_iter=500)
tsne_results_img = tsne.fit_transform(img_data)

# %%
tsne_1 = tsne_results_img[:, 0]
tsne_2 = tsne_results_img[:, 1]
plt.title("TSNE PLot for Image Data with 2 components")
plt.scatter(tsne_1, tsne_2)

# %%
tsne = TSNE(n_components=2, verbose=0, perplexity=30, n_iter=500)
tsne_results_pca = tsne.fit_transform(pca_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df042372d987> in <module>
# ----> 1 tsne = TSNE(n_components=2, verbose=0, perplexity=30, n_iter=500)
#       2 tsne_results_pca = tsne.fit_transform(pca_results)
#
# NameError: name 'TSNE' is not defined

# %%
tsne_1 = tsne_results[:, 0]
tsne_2 = tsne_results[:, 1]
plt.title("TSNE PLot on PCA Components ")
plt.scatter(tsne_1, tsne_2)

# %%
cluster_li = []
for each in range(0,len(cluster)):
    for i in cluster[each]:
        cluster_li.append(i)

# %%
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, cluster_li):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

# %% [markdown]
# ### TSNE and KMeans CLustering

# %%
ax = df_result_tsne.plot.scatter(
    x = 'tsne1',
    y = 'tsne2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("KMeans Clustering -> T-SNE Plot")
# Out:
# Text(0.5, 1.0, 'KMeans Clustering -> T-SNE Plot')

# %% [markdown]
# ### PCA

# %%
# PCA on full dataset of 5000 images
pca = PCA( 
        n_components = 2,
        svd_solver = 'auto')
pca.fit(img_data)
pca_results = pca.transform(img_data)

# %%
label = np.array(df_stratified.label)
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'label'])

for i, j, k in zip(pca_1, pca_2, label):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'label' : int(k)}, ignore_index=True)

# %%
ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'label',
    cmap = 'viridis',
    alpha = 0.2
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA with original Labels")
# Out:
# Text(0.5, 1.0, 'PCA with original Labels')

# %%
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, cluster_li):
    df_result_tsne = df_result_tsne.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

# %% [markdown]
# ### PCA and KMeans Clustering

# %%
ax = df_result_tsne.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("KMeans Clustering -> PCA Plot")
# Out:
# Text(0.5, 1.0, 'KMeans Clustering -> PCA Plot')

# %% [markdown]
# ### KMeans on PCA Components

# %%
cluster = []
# for i in range(1,6):
kmeans = KMeans(n_clusters = 5)
kmeans.fit(pca_results)
cluster.append(kmeans.predict(pca_results))

# %%
cluster_li = []
for each in range(0,len(cluster)):
    for i in cluster[each]:
        cluster_li.append(i)

# %%
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, cluster_li):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

# %%
ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA Components -> KMeans Clustering")
# Out:
# Text(0.5, 1.0, 'PCA Components -> KMeans Clustering')

# %% [markdown]
# ### KMeans on TSNE Components

# %%
cluster = []
# for i in range(1,6):
kmeans = KMeans(n_clusters = 5)
kmeans.fit(tsne_results)
cluster.append(kmeans.predict(tsne_results))

cluster_li = []
for each in range(0,len(cluster)):
    for i in cluster[each]:
        cluster_li.append(i)

# %%
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'label'])

for i, j, k in zip(tsne_1, tsne_2, label):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'label' : int(k)}, ignore_index=True)

# %%
ax = df_result_tsne.plot.scatter(
    x = 'tsne1',
    y = 'tsne2',
    c = 'label',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot on Original Labels")
# Out:
# Text(0.5, 1.0, 'T-SNE Plot on Original Labels')

# %%
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, cluster_li):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

# %%
ax = df_result_tsne.plot.scatter(
    x = 'tsne1',
    y = 'tsne2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.8
)
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot -> KMeans Clustering")
# Out:
# Text(0.5, 1.0, 'T-SNE Plot -> KMeans Clustering')

# %% [markdown]
# ### GMM Clustering with PCA and T-SNE

# %%
cluster_gmm = []
gmm = GMM(n_components = 5)
gmm.fit(tsne_results)
cluster_gmm.append(gmm.predict(tsne_results))

# %%
cluster_li = []
for each in range(0,len(cluster_gmm)):
    for i in cluster_gmm[each]:
        cluster_li.append(i)
        
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, cluster_li):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_tsne.plot.scatter(
x = 'tsne1',
y = 'tsne2',
c = 'cluster',
cmap = 'viridis',
alpha = 0.8
)
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot -> GMM Clustering")
# Out:
# Text(0.5, 1.0, 'T-SNE Plot -> GMM Clustering')

# %%
cluster_gmm = []
gmm = GMM(n_components = 5)
gmm.fit(pca_results)
cluster_gmm.append(gmm.predict(pca_results))

# %%
gmm.means_
# Out:
# array([[-2.61905804e+01,  6.13864257e+00, -2.75037105e+00,
#          1.96067005e+00,  6.83490714e-01,  1.26862577e-01,
#         -4.21644144e-01,  1.50833875e+00, -8.91930660e-02,
#          7.74226566e-02,  8.86386532e-02, -1.90243893e-01,
#         -5.43893001e-02, -3.04754964e-01, -4.10496918e-01,
#          1.62960305e-01,  1.61592674e-01,  3.15272091e-01,
#          1.62931689e-01, -1.12259719e-01, -1.24020148e-01,
#          1.92925869e-01, -1.57656596e-02,  7.97879562e-03,
#         -1.03910659e-01, -7.13542727e-02,  8.81419875e-02,
#         -9.16026529e-02,  3.80200297e-03,  7.82733170e-02,
#          5.11919318e-03,  1.14706447e-02, -9.67089622e-02,
#          1.08677952e-02, -1.15569765e-02, -3.98083472e-02,
#         -4.79043105e-02,  9.66072852e-03, -1.30166388e-02,
#         -3.32220685e-02,  1.18382087e-01,  8.42115400e-04,
#         -1.03943188e-01,  7.63463704e-03,  9.97719319e-02,
#         -5.75656909e-04,  1.08606390e-01, -4.81986755e-02,
#         -2.09005959e-02,  5.33077832e-03, -5.10104998e-02,
#         -1.27978434e-02,  2.64204624e-02,  7.86465138e-03,
#         -1.43251798e-02, -3.49447773e-02, -2.69826588e-02,
#         -1.85861999e-02, -4.84665748e-02, -3.33434215e-02,
#          1.20907240e-02,  2.47331693e-02, -2.82936108e-02,
#          2.25343692e-02,  1.36160211e-02,  2.45719970e-02,
#         -1.43375818e-02,  3.47148037e-02,  1.57824208e-03,
#         -5.49190087e-03, -1.62310959e-03, -1.56068407e-02,
#         -1.62734488e-02,  2.03144126e-02, -2.01249876e-02,
#         -4.19944559e-02,  1.39406874e-02, -8.28028343e-03,
#         -1.10969033e-02, -3.81353067e-02, -3.16558984e-03,
#          6.39136687e-03, -1.67339748e-02,  3.26274208e-02,
#         -7.94301121e-02,  2.10806492e-01, -2.44846377e-01,
#          1.65058708e-01, -1.82226814e-01,  6.36352021e-02,
#          9.10984617e-03, -9.79544420e-02,  1.10438187e-01,
#         -5.87548328e-02, -1.59627793e-01,  8.81009774e-03,
#          1.21679255e-01, -1.08607378e-01,  9.18183987e-02,
#         -9.01967724e-02,  2.95197909e-01, -3.92809462e-02,
#          1.56777112e-02,  6.15139094e-02, -2.96551406e-02,
#         -2.06049828e-01,  1.09763814e-01, -9.94474910e-02,
#          9.82661860e-02,  9.75770842e-02,  2.32109156e-02,
#         -8.33569396e-02, -8.09881687e-03, -2.74380867e-02,
#         -5.47430910e-02, -6.17178593e-02,  3.84326296e-02,
#         -3.92652393e-03,  1.50716810e-01,  2.55681346e-01,
#         -5.02821836e-02, -2.42904449e-02,  4.40085071e-03,
#         -5.59306533e-02,  8.25173328e-03,  1.72213648e-02,
#          4.78223375e-02, -9.25839432e-02,  3.78001050e-02,
#          3.25728712e-02,  3.10012632e-02, -9.75718117e-02,
#         -7.05373398e-02, -8.44082427e-02, -5.35215239e-02,
#          1.97285473e-03,  6.20978923e-02,  3.43638610e-02,
#         -1.22185121e-01, -2.43217188e-02,  4.38597964e-03,
#          2.02595127e-02,  7.81576497e-02, -8.38346948e-02,
#         -2.31573497e-02, -5.56623185e-02, -1.51358578e-01,
#          1.42227942e-01, -4.59774343e-02,  2.39689715e-02,
#         -3.34469717e-02, -2.29020543e-03, -6.46962521e-02,
#          7.61829252e-02,  4.42138548e-02,  1.16445386e-02,
#          8.14931433e-02,  5.67854235e-02, -1.09675768e-01,
#          5.68408408e-02,  3.76217152e-02,  5.08824395e-02,
#         -3.59045676e-02,  1.53137093e-02,  3.13569758e-02,
#         -8.29354596e-02, -5.12855981e-02,  4.29220055e-02,
#         -4.02199878e-02,  4.91319227e-02, -4.36905691e-02]])

# %%
# label = np.array(df_stratified.label)

cluster_li = []
for each in range(0,len(cluster_gmm)):
    for i in cluster_gmm[each]:
        cluster_li.append(i)
        
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, cluster_li):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA -> GMM Clustering")
# Out:
# Text(0.5, 1.0, 'PCA -> GMM Clustering')

# %%
# TRY WITH 150 COmponent
pca_150 = PCA( 
        n_components = 150,
        svd_solver = 'auto')
pca_150.fit(img_data)
pca_results_150 = pca_150.transform(img_data)

pca_1_150 = pca_results_150[:, 0]
pca_2_150 = pca_results_150[:, 1]

cluster_gmm = []
gmm = GMM(n_components = 5)
gmm.fit(pca_results_150)
cluster_gmm.append(gmm.predict(pca_results_150))
cluster_li = []
for each in range(0,len(cluster_gmm)):
    for i in cluster_gmm[each]:
        cluster_li.append(i)
        
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1_150, pca_2_150, cluster_li):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA -> GMM Clustering")
# Out:
# Text(0.5, 1.0, 'PCA -> GMM Clustering')

# %% [markdown]
# ### Agglomerative Clustering on PCA  components

# %%
clustering_img = AgglomerativeClustering(
linkage='ward',
n_clusters = 5).fit(pca_results)
labels = clustering_img.labels_

# %%
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, labels):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA -> Agglomerative Clustering[Linkage-WARD]")
# Out:
# Text(0.5, 1.0, 'PCA -> Agglomerative Clustering[Linkage-WARD]')

# %%
clustering_pca_average = AgglomerativeClustering(
linkage='average',
n_clusters = 5).fit(pca_results)
labels = clustering_pca_average.labels_

# %%
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, labels):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA -> Agglomerative Clustering[Linkage-AVERAGE]")
# Out:
# Text(0.5, 1.0, 'PCA -> Agglomerative Clustering[Linkage-AVERAGE]')

# %%
clustering_pca_comp = AgglomerativeClustering(
linkage='complete',
n_clusters = 5).fit(pca_results)
labels = clustering_pca_comp.labels_

# %%
df_result_pca = pd.DataFrame(columns = ['pca1', 'pca2', 'cluster'])

for i, j, k in zip(pca_1, pca_2, labels):
    df_result_pca = df_result_pca.append({'pca1' : i, 'pca2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_pca.plot.scatter(
    x = 'pca1',
    y = 'pca2',
    c = 'cluster',
    cmap = 'viridis',
    alpha = 0.5
)
ax.set_xlabel("PCA 1")
ax.set_ylabel("PCA 2")
ax.set_title("PCA -> Agglomerative Clustering[Linkage-Complete]")
# Out:
# Text(0.5, 1.0, 'PCA -> Agglomerative Clustering[Linkage-Complete]')

# %% [markdown]
# ### Agglomerative Clustering on TSNE Components

# %%
clustering_img = AgglomerativeClustering(
linkage='ward',
n_clusters = 5).fit(tsne_results)
labels = clustering_img.labels_

# %%
        
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, labels):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_tsne.plot.scatter(
x = 'tsne1',
y = 'tsne2',
c = 'cluster',
cmap = 'viridis',
alpha = 0.8)

ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot -> Agglomerative Clustering[Linkage-WARD]")
plt.show()

# %%
clustering_img_average = AgglomerativeClustering(
linkage='average',
n_clusters = 5).fit(tsne_results)
labels = clustering_img_average.labels_

# %%
        
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, labels):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_tsne.plot.scatter(
x = 'tsne1',
y = 'tsne2',
c = 'cluster',
cmap = 'viridis',
alpha = 0.8)

ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot -> Agglomerative Clustering[Linkage - Average]")
plt.show()

# %%
clustering_img_complete = AgglomerativeClustering(
linkage='complete',
n_clusters = 5).fit(tsne_results)
labels = clustering_img_complete.labels_

# %%
        
df_result_tsne = pd.DataFrame(columns = ['tsne1', 'tsne2', 'cluster'])

for i, j, k in zip(tsne_1, tsne_2, labels):
    df_result_tsne = df_result_tsne.append({'tsne1' : i, 'tsne2' : j, 'cluster' : int(k)}, ignore_index=True)

ax = df_result_tsne.plot.scatter(
x = 'tsne1',
y = 'tsne2',
c = 'cluster',
cmap = 'viridis',
alpha = 0.8)

ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
ax.set_title("T-SNE Plot -> Agglomerative Clustering[Linkage - COMPLETE]")
plt.show()

# %% [markdown]
# ### TRYING Recommendation with KMeans

# %%
model = KMeans(n_clusters=5).fit(img_data)

# %%
model.cluster_centers_
# Out:
# array([[0.99317593, 0.99295059, 0.99249655, ..., 0.99346181, 0.99321293,
#         0.99292705],
#        [0.9948367 , 0.99420717, 0.99335817, ..., 0.99329464, 0.99297698,
#         0.99215686],
#        [0.9979634 , 0.99790138, 0.99777043, ..., 0.99768083, 0.9974465 ,
#         0.99729143],
#        [0.99247387, 0.99217053, 0.99159937, ..., 0.99284553, 0.99256405,
#         0.99204755],
#        [0.998302  , 0.99824136, 0.99807291, ..., 0.99832895, 0.99826157,
#         0.99811333]])

# %%
x = np.reshape(img_data[12], (1, len(img_data[0])))
print(model.predict(x))

y = np.reshape(x, (120,120,3))
plt.imshow(y)
# Out:
# [0]

# %%
x = np.reshape(img_data[1400], (1, len(img_data[1])))
print(model.predict(x))
y = np.reshape(x, (120,120,3))
plt.imshow(y)
# Out:
# [1]

# %%
x = np.reshape(img_data[3100], (1, len(img_data[1])))
print(model.predict(x))
y = np.reshape(x, (120,120,3))
plt.imshow(y)
# Out:
# [2]

# %%
x = np.reshape(img_data[4999], (1, len(img_data[1])))
print(model.predict(x))
y = np.reshape(x, (120,120,3))
plt.imshow(y)
# Out:
# [2]

# %%
x = np.reshape(img_data[2000], (1, len(img_data[1])))
print(model.predict(x))
y = np.reshape(x, (120,120,3))
plt.imshow(y)
# Out:
# [3]

# %%
labels = model.predict(img_data)

# %%
df_stratified['pred_labels'] = labels

# %%
df_sport = df_stratified[4000:5000]

# %%
li = []
for i in df_sport['pred_labels']:
    li.append(i)

# %%
li.count(0), li.count(3), li.count(1), li.count(4), li.count(2)
# Out:
# (33, 353, 1, 492, 121)

# %%
df_formal = df_stratified[1000:2000]
li = []
for i in df_formal['pred_labels']:
    li.append(i)

# %%
li.count(0), li.count(3), li.count(1), li.count(4), li.count(2)
# Out:
# (2, 66, 267, 31, 634)

# %%
df_stratified
# Out:
#          id  label  pred_labels
# 0     55627      0            0
# 1     23930      0            0
# 2     22114      0            3
# 3      8996      0            0
# 4     24666      0            3
# 5     13083      0            0
# 6     29568      0            0
# 7     22702      0            3
# 8     20681      0            0
# 9      3640      0            0
# 10     1920      0            0
# 11    43879      0            3
# 12    39658      0            0
# 13     6474      0            0
# 14     6802      0            0
# 15    29233      0            0
# 16    15247      0            3
# 17    59330      0            3
# 18    44741      0            3
# 19    23679      0            0
# 20     5332      0            0
# 21     4142      0            0
# 22    57517      0            0
# 23     3597      0            3
# 24    42272      0            3
# 25    59938      0            0
# 26    54068      0            0
# 27     5873      0            3
# 28    36480      0            0
# 29    34082      0            0
# ...     ...    ...          ...
# 4970  21679      4            4
# 4971  45229      4            0
# 4972  29949      4            2
# 4973  56318      4            3
# 4974  33909      4            3
# 4975  40504      4            2
# 4976  52665      4            4
# 4977  25613      4            3
# 4978  51562      4            4
# 4979  46419      4            4
# 4980  49870      4            3
# 4981  45236      4            4
# 4982  33922      4            3
# 4983  23514      4            4
# 4984   8110      4            4
# 4985  45214      4            3
# 4986  37470      4            3
# 4987  43193      4            2
# 4988  25638      4            3
# 4989  29932      4            4
# 4990  47994      4            3
# 4991  46554      4            4
# 4992  46541      4            3
# 4993  45249      4            4
# 4994  32377      4            2
# 4995  50394      4            2
# 4996  29494      4            0
# 4997  45204      4            3
# 4998  11204      4            4
# 4999  59231      4            2
#
# [5000 rows x 3 columns]

# %%
df_formal = df_stratified[4000:4999]
li = []
for i in df_formal['pred_labels']:
    li.append(i)

# %%
li.count(0), li.count(3), li.count(1), li.count(4), li.count(2)
# Out:
# (33, 353, 1, 492, 120)

# %%
filepath = 'C:/fashion-dataset/fashion-dataset/images/'+str(2367)+'.jpg'  
temp = load_img(filepath, target_size = (120, 120, 3))
temp = img_to_array(temp).flatten()
temp /= 255

# %%
test_data = np.reshape(temp, (1,43200))
plt.imshow(np.reshape(test_data, (120,120,3)))

# %%
x = model.predict(test_data)

# %%
map_dict = {'0':0,
           '1': 3,
            '2':1,
            '3':2,
            '4':4
           }
def cluster_predict(i, map_dict):
    return map_dict[str(i)]

# %%
# Prediciting the right cluster image
cluster_id = cluster_predict(int(x), map_dict)
# Out:
# 0

# %%
images= []
def id_retrieve(df_stratified, cluster_id):
    if df_stratified['label'] == cluster_id:
        images.append(df_stratified['id'])

# %%
df_stratified
# Out:
#          id  label  pred_labels
# 0     55627      0            0
# 1     23930      0            0
# 2     22114      0            3
# 3      8996      0            0
# 4     24666      0            3
# 5     13083      0            0
# 6     29568      0            0
# 7     22702      0            3
# 8     20681      0            0
# 9      3640      0            0
# 10     1920      0            0
# 11    43879      0            3
# 12    39658      0            0
# 13     6474      0            0
# 14     6802      0            0
# 15    29233      0            0
# 16    15247      0            3
# 17    59330      0            3
# 18    44741      0            3
# 19    23679      0            0
# 20     5332      0            0
# 21     4142      0            0
# 22    57517      0            0
# 23     3597      0            3
# 24    42272      0            3
# 25    59938      0            0
# 26    54068      0            0
# 27     5873      0            3
# 28    36480      0            0
# 29    34082      0            0
# ...     ...    ...          ...
# 4970  21679      4            4
# 4971  45229      4            0
# 4972  29949      4            2
# 4973  56318      4            3
# 4974  33909      4            3
# 4975  40504      4            2
# 4976  52665      4            4
# 4977  25613      4            3
# 4978  51562      4            4
# 4979  46419      4            4
# 4980  49870      4            3
# 4981  45236      4            4
# 4982  33922      4            3
# 4983  23514      4            4
# 4984   8110      4            4
# 4985  45214      4            3
# 4986  37470      4            3
# 4987  43193      4            2
# 4988  25638      4            3
# 4989  29932      4            4
# 4990  47994      4            3
# 4991  46554      4            4
# 4992  46541      4            3
# 4993  45249      4            4
# 4994  32377      4            2
# 4995  50394      4            2
# 4996  29494      4            0
# 4997  45204      4            3
# 4998  11204      4            4
# 4999  59231      4            2
#
# [5000 rows x 3 columns]

# %%
display_recommendation_cosine(test_data, 5)
# Out:
# [array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#        0.99215686], dtype=float32), array([0.8392157 , 0.827451  , 0.8       , ..., 0.78039217, 0.76862746,
#        0.7411765 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99215686, 0.99215686, 0.99215686, ..., 0.99215686, 0.99215686,
#        0.99215686], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9882353, 0.9882353, 0.9882353, ..., 0.9882353, 0.9882353,
#        0.9882353], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.93333334, 0.93333334, 0.93333334, ..., 0.93333334, 0.93333334,
#        0.93333334], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7607843 , 0.7490196 , 0.7294118 , ..., 0.7529412 , 0.7411765 ,
#        0.72156864], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.8745098 , 0.8784314 , 0.8862745 , ..., 0.8784314 , 0.8862745 ,
#        0.88235295], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99215686, 1.        , 0.99607843, ..., 0.99215686, 1.        ,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7529412 , 0.7411765 ,
#        0.72156864], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#        0.99215686], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7607843 , 0.7490196 , 0.7294118 , ..., 0.7529412 , 0.7411765 ,
#        0.72156864], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.75686276, 0.74509805,
#        0.7254902 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#        0.99215686], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.6392157 , 0.63529414, 0.61960787, ..., 0.8784314 , 0.8745098 ,
#        0.89411765], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.75686276, 0.74509805,
#        0.7254902 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.9882353 , 0.99215686, ..., 0.99607843, 0.9882353 ,
#        0.99215686], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.76862746, 0.75686276,
#        0.7294118 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7607843, 0.7490196, 0.7294118, ..., 0.7490196, 0.7372549,
#        0.7176471], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99215686, 0.99215686, 0.99215686, ..., 0.99215686, 0.99215686,
#        0.99215686], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#        0.7176471 ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
# ...
#        1.        ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.9843137, 0.9843137, 0.9843137, ..., 0.9843137, 0.9843137,
#        0.9843137], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.99607843, 0.99607843, ..., 0.99607843, 0.99607843,
#        0.99607843], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([1., 1., 1., ..., 1., 1., 1.], dtype=float32), array([0.99607843, 0.9882353 , 0.99215686, ..., 1.        , 1.        ,
#        1.        ], dtype=float32), array([[0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ]], dtype=float32), array([[0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ]], dtype=float32), array([[0.7647059 , 0.7529412 , 0.73333335, ..., 0.7490196 , 0.7372549 ,
#         0.7176471 ]], dtype=float32)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-441-c6e80b4a5400> in <module>
# ----> 1 display_recommendation_cosine(test_data, 5)
#
# <ipython-input-440-1fbcccbe320b> in display_recommendation_cosine(ref_img, top_n)
#       2
#       3     #Getting recommendations
# ----> 4     idx_rec, idx_sim = get_recommendation_cosine(ref_img, top_n)
#       5     rec_images = []
#       6     for r in idx_rec:
#
# <ipython-input-439-bb5927c724f7> in get_recommendation_cosine(img, top_n)
#       4     l = len(temp)
#       5     print(temp)
# ----> 6     cosine_sim = 1 - pairwise_distances(temp, metric='cosine')
#       7     sim_scores = list(enumerate(cosine_sim[l-1]))
#       8     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1586         func = partial(distance.cdist, metric=metric, **kwds)
#    1587
# -> 1588     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1589
#    1590
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1204
#    1205     if effective_n_jobs(n_jobs) == 1:
# -> 1206         return func(X, Y, **kwds)
#    1207
#    1208     # enforce a threading backend to prevent data communication overhead
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_distances(X, Y)
#     679     """
#     680     # 1.0 - cosine_similarity(X, Y) without copy
# --> 681     S = cosine_similarity(X, Y)
#     682     S *= -1
#     683     S += 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1025     # to avoid recursive import
#    1026
# -> 1027     X, Y = check_pairwise_arrays(X, Y)
#    1028
#    1029     X_normalized = normalize(X, copy=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype)
#     110     else:
#     111         X = check_array(X, accept_sparse='csr', dtype=dtype,
# --> 112                         estimator=estimator)
#     113         Y = check_array(Y, accept_sparse='csr', dtype=dtype,
#     114                         estimator=estimator)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: setting an array element with a sequence.

# %%
def get_recommendation_cosine(img, top_n):
    temp = img_data
    temp.append(img)
    l = len(temp)
    print(temp)
    cosine_sim = 1 - pairwise_distances(temp, metric='cosine')
    sim_scores = list(enumerate(cosine_sim[l-1]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]
    idx_rec    = [i[0] for i in sim_scores]
    idx_sim    = [i[1] for i in sim_scores]
    return idx_rec, idx_sim

# %%
def display_recommendation_cosine(ref_img, top_n):
    
    #Getting recommendations
    idx_rec, idx_sim = get_recommendation_cosine(ref_img, top_n)
    rec_images = []
    for r in idx_rec:
        rec_images.append(X_img_train[r])
    rec_images = np.array(rec_images)
    
    #plotting original image
    pyplot.imshow(np.uint8(ref_img*255).reshape(80, 60, 3))
    pyplot.title("Original Image")
    pyplot.show()
    
    #Plotting recommendations
    fig, ax = pyplot.subplots(1, top_n, figsize=(8, 3))
    rec = rec_images.reshape(top_n, 80, 60, 3)
    for axi, center in zip(ax.flat, rec):
        axi.set(xticks=[], yticks=[])
        axi.imshow(center, interpolation='nearest', cmap=pyplot.cm.binary)
