# %%
# ResNet50

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
model = ResNet50(weights='imagenet', include_top = False)

img_path = './Data_original/images/1581.jpg'
img = image.load_img(img_path, target_size=(224, 224, 3))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
# print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_149[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_150[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 56, 56, 256)  0           add_49[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_151[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_152[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_153[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 56, 56, 256)  0           add_50[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_154[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_155[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_156[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_154[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 56, 56, 256)  0           add_51[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_158[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_159[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 28, 28, 512)  0           add_52[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_160[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_161[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_162[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_160[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 28, 28, 512)  0           add_53[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_163[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_164[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_165[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 28, 28, 512)  0           add_54[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_166[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_167[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_168[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_166[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 28, 28, 512)  0           add_55[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_170[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_171[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 14, 14, 1024) 0           add_56[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_172[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_173[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_174[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 14, 14, 1024) 0           add_57[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_175[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_176[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_177[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_175[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 14, 14, 1024) 0           add_58[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_178[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_179[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_180[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 14, 14, 1024) 0           add_59[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_181[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_182[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_183[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 14, 14, 1024) 0           add_60[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_184[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_185[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_186[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_184[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 14, 14, 1024) 0           add_61[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_188[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_189[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 7, 7, 2048)   0           add_62[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_190[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_191[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_192[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 7, 7, 2048)   0           add_63[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_193[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_194[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_195[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_193[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 7, 7, 2048)   0           add_64[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_196[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
len(model.layers)
# Out:
# 177

# %%
for l in model.layers:
    print (l.output)
# Out:
# Tensor("input_4:0", shape=(?, 224, 224, 3), dtype=float32)
# Tensor("conv1_pad_3/Pad:0", shape=(?, 230, 230, 3), dtype=float32)
# Tensor("conv1_3/BiasAdd:0", shape=(?, 112, 112, 64), dtype=float32)
# Tensor("bn_conv1_3/cond/Merge:0", shape=(?, 112, 112, 64), dtype=float32)
# Tensor("activation_148/Relu:0", shape=(?, 112, 112, 64), dtype=float32)
# Tensor("pool1_pad_3/Pad:0", shape=(?, 114, 114, 64), dtype=float32)
# Tensor("max_pooling2d_4/MaxPool:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2a_branch2a_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2a_branch2a_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_149/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2a_branch2b_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2a_branch2b_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_150/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2a_branch2c_3/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("res2a_branch1_3/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("bn2a_branch2c_3/cond/Merge:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("bn2a_branch1_3/cond/Merge:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("add_49/add:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("activation_151/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("res2b_branch2a_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2b_branch2a_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_152/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2b_branch2b_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2b_branch2b_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_153/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2b_branch2c_3/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("bn2b_branch2c_3/cond/Merge:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("add_50/add:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("activation_154/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("res2c_branch2a_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2c_branch2a_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_155/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2c_branch2b_3/BiasAdd:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("bn2c_branch2b_3/cond/Merge:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("activation_156/Relu:0", shape=(?, 56, 56, 64), dtype=float32)
# Tensor("res2c_branch2c_3/BiasAdd:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("bn2c_branch2c_3/cond/Merge:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("add_51/add:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("activation_157/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# Tensor("res3a_branch2a_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3a_branch2a_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_158/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3a_branch2b_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3a_branch2b_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_159/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3a_branch2c_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("res3a_branch1_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("bn3a_branch2c_3/cond/Merge:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("bn3a_branch1_3/cond/Merge:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("add_52/add:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("activation_160/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("res3b_branch2a_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3b_branch2a_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_161/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3b_branch2b_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3b_branch2b_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_162/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3b_branch2c_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("bn3b_branch2c_3/cond/Merge:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("add_53/add:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("activation_163/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("res3c_branch2a_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3c_branch2a_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_164/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3c_branch2b_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3c_branch2b_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_165/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3c_branch2c_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("bn3c_branch2c_3/cond/Merge:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("add_54/add:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("activation_166/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("res3d_branch2a_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3d_branch2a_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_167/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3d_branch2b_3/BiasAdd:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("bn3d_branch2b_3/cond/Merge:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("activation_168/Relu:0", shape=(?, 28, 28, 128), dtype=float32)
# Tensor("res3d_branch2c_3/BiasAdd:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("bn3d_branch2c_3/cond/Merge:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("add_55/add:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("activation_169/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Tensor("res4a_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4a_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_170/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4a_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4a_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_171/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4a_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4a_branch1_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4a_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4a_branch1_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_56/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_172/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4b_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4b_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_173/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4b_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4b_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_174/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4b_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4b_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_57/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_175/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4c_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4c_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_176/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4c_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4c_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_177/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4c_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4c_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_58/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_178/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4d_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4d_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_179/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4d_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4d_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_180/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4d_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4d_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_59/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_181/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4e_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4e_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_182/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4e_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4e_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_183/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4e_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4e_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_60/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_184/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res4f_branch2a_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4f_branch2a_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_185/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4f_branch2b_3/BiasAdd:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("bn4f_branch2b_3/cond/Merge:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("activation_186/Relu:0", shape=(?, 14, 14, 256), dtype=float32)
# Tensor("res4f_branch2c_3/BiasAdd:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("bn4f_branch2c_3/cond/Merge:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("add_61/add:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("activation_187/Relu:0", shape=(?, 14, 14, 1024), dtype=float32)
# Tensor("res5a_branch2a_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5a_branch2a_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_188/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5a_branch2b_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5a_branch2b_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_189/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5a_branch2c_3/BiasAdd:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("res5a_branch1_3/BiasAdd:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("bn5a_branch2c_3/cond/Merge:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("bn5a_branch1_3/cond/Merge:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("add_62/add:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("activation_190/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("res5b_branch2a_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5b_branch2a_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_191/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5b_branch2b_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5b_branch2b_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_192/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5b_branch2c_3/BiasAdd:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("bn5b_branch2c_3/cond/Merge:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("add_63/add:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("activation_193/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("res5c_branch2a_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5c_branch2a_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_194/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5c_branch2b_3/BiasAdd:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("bn5c_branch2b_3/cond/Merge:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("activation_195/Relu:0", shape=(?, 7, 7, 512), dtype=float32)
# Tensor("res5c_branch2c_3/BiasAdd:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("bn5c_branch2c_3/cond/Merge:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("add_64/add:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("activation_196/Relu:0", shape=(?, 7, 7, 2048), dtype=float32)
# Tensor("avg_pool/Mean:0", shape=(?, 2048), dtype=float32)
# Tensor("fc1000/Softmax:0", shape=(?, 1000), dtype=float32)

# %%
model.layers[-1].output
# Out:
# <tf.Tensor 'fc1000/Softmax:0' shape=(?, 1000) dtype=float32>

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
outputs
# Out:
# [<tf.Tensor 'input_4:0' shape=(?, 224, 224, 3) dtype=float32>,
#  <tf.Tensor 'conv1_pad_3/Pad:0' shape=(?, 230, 230, 3) dtype=float32>,
#  <tf.Tensor 'conv1_3/BiasAdd:0' shape=(?, 112, 112, 64) dtype=float32>,
#  <tf.Tensor 'bn_conv1_3/cond/Merge:0' shape=(?, 112, 112, 64) dtype=float32>,
#  <tf.Tensor 'activation_148/Relu:0' shape=(?, 112, 112, 64) dtype=float32>,
#  <tf.Tensor 'pool1_pad_3/Pad:0' shape=(?, 114, 114, 64) dtype=float32>,
#  <tf.Tensor 'max_pooling2d_4/MaxPool:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2a_branch2a_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2a_branch2a_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_149/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2a_branch2b_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2a_branch2b_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_150/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2a_branch2c_3/BiasAdd:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'res2a_branch1_3/BiasAdd:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'bn2a_branch2c_3/cond/Merge:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'bn2a_branch1_3/cond/Merge:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'add_49/add:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'activation_151/Relu:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'res2b_branch2a_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2b_branch2a_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_152/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2b_branch2b_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2b_branch2b_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_153/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2b_branch2c_3/BiasAdd:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'bn2b_branch2c_3/cond/Merge:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'add_50/add:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'activation_154/Relu:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'res2c_branch2a_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2c_branch2a_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_155/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2c_branch2b_3/BiasAdd:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'bn2c_branch2b_3/cond/Merge:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'activation_156/Relu:0' shape=(?, 56, 56, 64) dtype=float32>,
#  <tf.Tensor 'res2c_branch2c_3/BiasAdd:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'bn2c_branch2c_3/cond/Merge:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'add_51/add:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'activation_157/Relu:0' shape=(?, 56, 56, 256) dtype=float32>,
#  <tf.Tensor 'res3a_branch2a_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3a_branch2a_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_158/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3a_branch2b_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3a_branch2b_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_159/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3a_branch2c_3/BiasAdd:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'res3a_branch1_3/BiasAdd:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'bn3a_branch2c_3/cond/Merge:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'bn3a_branch1_3/cond/Merge:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'add_52/add:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'activation_160/Relu:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'res3b_branch2a_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3b_branch2a_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_161/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3b_branch2b_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3b_branch2b_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_162/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3b_branch2c_3/BiasAdd:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'bn3b_branch2c_3/cond/Merge:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'add_53/add:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'activation_163/Relu:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'res3c_branch2a_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3c_branch2a_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_164/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3c_branch2b_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3c_branch2b_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_165/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3c_branch2c_3/BiasAdd:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'bn3c_branch2c_3/cond/Merge:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'add_54/add:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'activation_166/Relu:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'res3d_branch2a_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3d_branch2a_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_167/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3d_branch2b_3/BiasAdd:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'bn3d_branch2b_3/cond/Merge:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'activation_168/Relu:0' shape=(?, 28, 28, 128) dtype=float32>,
#  <tf.Tensor 'res3d_branch2c_3/BiasAdd:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'bn3d_branch2c_3/cond/Merge:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'add_55/add:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'activation_169/Relu:0' shape=(?, 28, 28, 512) dtype=float32>,
#  <tf.Tensor 'res4a_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4a_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_170/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4a_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4a_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_171/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4a_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4a_branch1_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4a_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4a_branch1_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_56/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_172/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4b_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4b_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_173/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4b_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4b_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_174/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4b_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4b_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_57/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_175/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4c_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4c_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_176/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4c_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4c_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_177/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4c_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4c_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_58/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_178/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4d_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4d_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_179/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4d_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4d_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_180/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4d_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4d_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_59/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_181/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4e_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4e_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_182/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4e_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4e_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_183/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4e_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4e_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_60/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_184/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res4f_branch2a_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4f_branch2a_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_185/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4f_branch2b_3/BiasAdd:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'bn4f_branch2b_3/cond/Merge:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'activation_186/Relu:0' shape=(?, 14, 14, 256) dtype=float32>,
#  <tf.Tensor 'res4f_branch2c_3/BiasAdd:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'bn4f_branch2c_3/cond/Merge:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'add_61/add:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'activation_187/Relu:0' shape=(?, 14, 14, 1024) dtype=float32>,
#  <tf.Tensor 'res5a_branch2a_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5a_branch2a_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_188/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5a_branch2b_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5a_branch2b_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_189/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5a_branch2c_3/BiasAdd:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'res5a_branch1_3/BiasAdd:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'bn5a_branch2c_3/cond/Merge:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'bn5a_branch1_3/cond/Merge:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'add_62/add:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'activation_190/Relu:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'res5b_branch2a_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5b_branch2a_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_191/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5b_branch2b_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5b_branch2b_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_192/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5b_branch2c_3/BiasAdd:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'bn5b_branch2c_3/cond/Merge:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'add_63/add:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'activation_193/Relu:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'res5c_branch2a_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5c_branch2a_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_194/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5c_branch2b_3/BiasAdd:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'bn5c_branch2b_3/cond/Merge:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'activation_195/Relu:0' shape=(?, 7, 7, 512) dtype=float32>,
#  <tf.Tensor 'res5c_branch2c_3/BiasAdd:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'bn5c_branch2c_3/cond/Merge:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'add_64/add:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'activation_196/Relu:0' shape=(?, 7, 7, 2048) dtype=float32>,
#  <tf.Tensor 'avg_pool/Mean:0' shape=(?, 2048) dtype=float32>,
#  <tf.Tensor 'fc1000/Softmax:0' shape=(?, 1000) dtype=float32>]

# %%
from keras import backend as K

inp = model.input                                           # input placeholder
outputs = [layer.output for layer in model.layers][:]  

input_shape = (224, 244, 3)

funcs = [K.function(inp + [K.learning_phase()], [out]) for out in outputs]

# Testing
test = np.random.random(input_shape)[np.newaxis,...]


# functors[1]([x[0]])

layer_outs = [func([test, x[0]]) for func in functors]
print (layer_outs)

# %%
x[0].reshape((1, 224, 224, 3)).shape
# Out:
# (1, 224, 224, 3)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
import keras.backend as K
K.clear_session()

# %%
layer_outs = [func([x]) for func in funcs]
print (layer_outs)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-71-77d0481b4906> in <module>
# ----> 1 layer_outs = [func([x]) for func in funcs]
#       2 print (layer_outs)
#
# <ipython-input-71-77d0481b4906> in <listcomp>(.0)
# ----> 1 layer_outs = [func([x]) for func in funcs]
#       2 print (layer_outs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3287         feed_symbols != self._feed_symbols or self.fetches != self._fetches or
#    3288         session != self._session):
# -> 3289       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in _make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    3220       callable_opts.run_options.CopyFrom(self.run_options)
#    3221     # Create callable.
# -> 3222     callable_fn = session._make_callable_from_options(callable_opts)
#    3223     # Cache parameters corresponding to the generated callable, so that
#    3224     # we can detect future mismatches and refresh the callable.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _make_callable_from_options(self, callable_options)
#    1487     """
#    1488     self._extend_graph()
# -> 1489     return BaseSession._Callable(self, callable_options)
#    1490
#    1491
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __init__(self, session, callable_options)
#    1444       try:
#    1445         self._handle = tf_session.TF_SessionMakeCallable(
# -> 1446             session._session, options_ptr)
#    1447       finally:
#    1448         tf_session.TF_DeleteBuffer(options_ptr)
#
# InvalidArgumentError: Tensor add_240:0, specified in either feed_devices or fetch_devices was not found in the Graph

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_148[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_149[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_150[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 56, 56, 256)  0           add_49[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_151[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_152[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_153[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 56, 56, 256)  0           add_50[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_154[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_155[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_156[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_154[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 56, 56, 256)  0           add_51[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_158[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_159[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_157[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 28, 28, 512)  0           add_52[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_160[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_161[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_162[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_160[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 28, 28, 512)  0           add_53[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_163[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_164[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_165[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 28, 28, 512)  0           add_54[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_166[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_167[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_168[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_166[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 28, 28, 512)  0           add_55[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_170[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_171[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_169[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 14, 14, 1024) 0           add_56[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_172[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_173[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_174[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 14, 14, 1024) 0           add_57[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_175[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_176[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_177[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_175[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 14, 14, 1024) 0           add_58[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_178[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_179[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_180[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_178[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 14, 14, 1024) 0           add_59[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_181[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_182[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_183[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 14, 14, 1024) 0           add_60[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_184[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_185[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_186[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_184[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 14, 14, 1024) 0           add_61[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_188[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_189[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_187[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 7, 7, 2048)   0           add_62[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_190[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_191[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_192[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 7, 7, 2048)   0           add_63[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_193[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_194[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_195[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_193[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 7, 7, 2048)   0           add_64[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_196[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# VGG16

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top = True)

img_path = './images/59752.jpg'
img = image.load_img(img_path, target_size=(224, 224,3))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# Predicted: [('n02837789', 'bikini', 0.8071391), ('n02892767', 'brassiere', 0.13684478), ('n03710637', 'maillot', 0.047432855)]
